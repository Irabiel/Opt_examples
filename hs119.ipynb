# %%
using JuMP, Ipopt

# %% [markdown]
# # Model hs119
#   Parameters
#
#     c[1] = 2.5
#     c[2] = 1.1
#     c[3] = -3.1
#     c[4] = -3.5
#     c[5] = 1.3
#     c[6] = 2.1
#     c[7] = 2.3
#     c[8] = -1.5
#
#   End Parameters
#
#   Variables
#
#     x[1:16] =10, >=0, <=5
#     obj
#
#   End Variables
#
#   Intermediates
#
#     s[1] = 0.22*x[1] + 0.2*x[2] + 0.19*x[3] + 0.25*x[4] + 0.15*x[5] + 0.11*x[6] + 0.12*x[7] + 0.13*x[8] + 1*x[9]
#     s[2] = -1.46*x[1] -1.3*x[3] + 1.82*x[4] -1.15*x[5] + 0.8*x[7] + 1*x[10]
#     s[3] = 1.29*x[1] -0.89*x[2] -1.16*x[5] -0.96*x[6] -0.49*x[8] + 1*x[11]
#     s[4] = -1.1*x[1] -1.06*x[2] + 0.95*x[3] -0.54*x[4] -1.78*x[6] -0.41*x[7] + 1*x[12]
#     s[5] = -1.43*x[4] + 1.51*x[5] + 0.59*x[6] -0.33*x[7] -0.43*x[8] + 1*x[13]
#     s[6] = -1.72*x[2] -0.33*x[3] + 1.62*x[5] + 1.24*x[6] + 0.21*x[7] -0.26*x[8] + 1*x[14]
#     s[7] = 1.12*x[1] + 0.31*x[4] + 1.12*x[7] -0.36*x[9] + 1*x[15]
#     s[8] = 0.45*x[2] + 0.26*x[3] -1.1*x[4] + 0.58*x[5] -1.03*x[7] + 0.1*x[8] + 1*x[16]
#
#     t[1] = (x[1]^2 + x[1] + 1) * (x[1]^2 + x[1] + 1)
#     t[2] = (x[1]^2 + x[1] + 1) * (x[4]^2 + x[4] + 1)
#     t[3] = (x[1]^2 + x[1] + 1) * (x[7]^2 + x[7] + 1)
#     t[4] = (x[1]^2 + x[1] + 1) * (x[8]^2 + x[8] + 1)
#     t[5] = (x[1]^2 + x[1] + 1) * (x[16]^2 + x[16] + 1)
#     t[6] = (x[2]^2 + x[2] + 1) * (x[2]^2 + x[2] + 1)
#     t[7] = (x[2]^2 + x[2] + 1) * (x[3]^2 + x[3] + 1)
#     t[8] = (x[2]^2 + x[2] + 1) * (x[7]^2 + x[7] + 1)
#     t[9] = (x[2]^2 + x[2] + 1) * (x[10]^2 + x[10] + 1)
#     t[10] = (x[3]^2 + x[3] + 1) * (x[3]^2 + x[3] + 1)
#     t[11] = (x[3]^2 + x[3] + 1) * (x[7]^2 + x[7] + 1)
#     t[12] = (x[3]^2 + x[3] + 1) * (x[9]^2 + x[9] + 1)
#     t[13] = (x[3]^2 + x[3] + 1) * (x[10]^2 + x[10] + 1)
#     t[14] = (x[3]^2 + x[3] + 1) * (x[14]^2 + x[14] + 1)
#     t[15] = (x[4]^2 + x[4] + 1) * (x[4]^2 + x[4] + 1)
#     t[16] = (x[4]^2 + x[4] + 1) * (x[7]^2 + x[7] + 1)
#     t[17] = (x[4]^2 + x[4] + 1) * (x[11]^2 + x[11] + 1)
#     t[18] = (x[4]^2 + x[4] + 1) * (x[15]^2 + x[15] + 1)
#     t[19] = (x[5]^2 + x[5] + 1) * (x[5]^2 + x[5] + 1)
#     t[20] = (x[5]^2 + x[5] + 1) * (x[6]^2 + x[6] + 1)
#     t[21] = (x[5]^2 + x[5] + 1) * (x[10]^2 + x[10] + 1)
#     t[22] = (x[5]^2 + x[5] + 1) * (x[12]^2 + x[12] + 1)
#     t[23] = (x[5]^2 + x[5] + 1) * (x[16]^2 + x[16] + 1)
#     t[24] = (x[6]^2 + x[6] + 1) * (x[6]^2 + x[6] + 1)
#     t[25] = (x[6]^2 + x[6] + 1) * (x[8]^2 + x[8] + 1)
#     t[26] = (x[6]^2 + x[6] + 1) * (x[15]^2 + x[15] + 1)
#     t[27] = (x[7]^2 + x[7] + 1) * (x[7]^2 + x[7] + 1)
#     t[28] = (x[7]^2 + x[7] + 1) * (x[11]^2 + x[11] + 1)
#     t[29] = (x[7]^2 + x[7] + 1) * (x[13]^2 + x[13] + 1)
#     t[30] = (x[8]^2 + x[8] + 1) * (x[8]^2 + x[8] + 1)
#     t[31] = (x[8]^2 + x[8] + 1) * (x[10]^2 + x[10] + 1)
#     t[32] = (x[8]^2 + x[8] + 1) * (x[15]^2 + x[15] + 1)
#     t[33] = (x[9]^2 + x[9] + 1) * (x[9]^2 + x[9] + 1)
#     t[34] = (x[9]^2 + x[9] + 1) * (x[12]^2 + x[12] + 1)
#     t[35] = (x[9]^2 + x[9] + 1) * (x[16]^2 + x[16] + 1)
#     t[36] = (x[10]^2 + x[10] + 1) * (x[10]^2 + x[10] + 1)
#     t[37] = (x[10]^2 + x[10] + 1) * (x[14]^2 + x[14] + 1)
#     t[38] = (x[11]^2 + x[11] + 1) * (x[11]^2 + x[11] + 1)
#     t[39] = (x[11]^2 + x[11] + 1) * (x[13]^2 + x[13] + 1)
#     t[40] = (x[11]^2 + x[11] + 1) * (x[12]^2 + x[12] + 1)
#     t[41] = (x[12]^2 + x[12] + 1) * (x[14]^2 + x[14] + 1)
#     t[42] = (x[13]^2 + x[13] + 1) * (x[13]^2 + x[13] + 1)
#     t[43] = (x[13]^2 + x[13] + 1) * (x[14]^2 + x[14] + 1)
#     t[44] = (x[14]^2 + x[14] + 1) * (x[14]^2 + x[14] + 1)
#     t[45] = (x[15]^2 + x[15] + 1) * (x[15]^2 + x[15] + 1)
#     t[46] = (x[16]^2 + x[16] + 1) * (x[16]^2 + x[16] + 1)
#
#     z[1] = t[1]
#     z[2:46] = z[1:45] + t[2:46]
#   End Intermediates
#
#
#   Equations
#     s[1:8] = c[1:8]
#
#     ! best known objective = 244.899698
#     obj = z[46]
#
#   End Equations
# End Model
#
#
# # optimal solution
#
#   x[1] = 0.03984735
#   x[2] = 0.7919832
#   x[3] = 0.2028703
#   x[4] = 0.8443579
#   x[5] = 1.126991
#   x[6] = 0.9347387
#   x[7] = 1.681962
#   x[8] = 0.1553009
#   x[9] = 1.567870
#   x[10] = 0
#   x[11] = 0
#   x[12] = 0
#   x[13] = 0.6602041
#   x[14] = 0
#   x[15] = 0.6742559
#   x[16] = 0

# %%
model = Model(Ipopt.Optimizer)

# %%
#Parameters
c = zeros(8);

c[1] = 2.5;
c[2] = 1.1;
c[3] = -3.1;
c[4] = -3.5;
c[5] = 1.3;
c[6] = 2.1;
c[7] = 2.3;
c[8] = -1.5;

# %%
#Variables

x0 = 10*ones(16)

@variable(model, x[i=1:16], start = x0[i])

@NLconstraint(model, [i=1:16], 0 <= x[i] <= 5)
# Out:
# 16-element Vector{NonlinearConstraintRef{ScalarShape}}:
#  0 ≤ x[1] ≤ 5
#  0 ≤ x[2] ≤ 5
#  0 ≤ x[3] ≤ 5
#  0 ≤ x[4] ≤ 5
#  0 ≤ x[5] ≤ 5
#  0 ≤ x[6] ≤ 5
#  0 ≤ x[7] ≤ 5
#  0 ≤ x[8] ≤ 5
#  0 ≤ x[9] ≤ 5
#  0 ≤ x[10] ≤ 5
#  0 ≤ x[11] ≤ 5
#  0 ≤ x[12] ≤ 5
#  0 ≤ x[13] ≤ 5
#  0 ≤ x[14] ≤ 5
#  0 ≤ x[15] ≤ 5
#  0 ≤ x[16] ≤ 5

# %%
y = Dict{Int, NonlinearExpression}()

y[1] = @NLexpression(model, 0.22*x[1] + 0.2*x[2] + 0.19*x[3] + 0.25*x[4] + 0.15*x[5] + 0.11*x[6] + 0.12*x[7] + 0.13*x[8] + 1*x[9])
y[2] = @NLexpression(model, -1.46*x[1] -1.3*x[3] + 1.82*x[4] -1.15*x[5] + 0.8*x[7] + 1*x[10])
y[3] = @NLexpression(model, 1.29*x[1] -0.89*x[2] -1.16*x[5] -0.96*x[6] -0.49*x[8] + 1*x[11])
y[4] = @NLexpression(model, -1.1*x[1] -1.06*x[2] + 0.95*x[3] -0.54*x[4] -1.78*x[6] -0.41*x[7] + 1*x[12])
y[5] = @NLexpression(model, -1.43*x[4] + 1.51*x[5] + 0.59*x[6] -0.33*x[7] -0.43*x[8] + 1*x[13])
y[6] = @NLexpression(model, -1.72*x[2] -0.33*x[3] + 1.62*x[5] + 1.24*x[6] + 0.21*x[7] -0.26*x[8] + 1*x[14])
y[7] = @NLexpression(model, 1.12*x[1] + 0.31*x[4] + 1.12*x[7] -0.36*x[9] + 1*x[15])
y[8] = @NLexpression(model, 0.45*x[2] + 0.26*x[3] -1.1*x[4] + 0.58*x[5] -1.03*x[7] + 0.1*x[8] + 1*x[16])

@NLconstraint(model, [i=1:8],  y[i] == c[i])
# Out:
# 8-element Vector{NonlinearConstraintRef{ScalarShape}}:
#  subexpression[1] - 2.5 = 0
#  subexpression[2] - 1.1 = 0
#  subexpression[3] - -3.1 = 0
#  subexpression[4] - -3.5 = 0
#  subexpression[5] - 1.3 = 0
#  subexpression[6] - 2.1 = 0
#  subexpression[7] - 2.3 = 0
#  subexpression[8] - -1.5 = 0

# %%
t = Dict{Int, NonlinearExpression}()

t[1] = @NLexpression(model,(x[1]^2 + x[1] + 1) * (x[1]^2 + x[1] + 1))
t[2] = @NLexpression(model,(x[1]^2 + x[1] + 1) * (x[4]^2 + x[4] + 1))
t[3] = @NLexpression(model,(x[1]^2 + x[1] + 1) * (x[7]^2 + x[7] + 1))
t[4] = @NLexpression(model,(x[1]^2 + x[1] + 1) * (x[8]^2 + x[8] + 1))
t[5] = @NLexpression(model,(x[1]^2 + x[1] + 1) * (x[16]^2 + x[16] + 1))
t[6] = @NLexpression(model,(x[2]^2 + x[2] + 1) * (x[2]^2 + x[2] + 1))
t[7] = @NLexpression(model,(x[2]^2 + x[2] + 1) * (x[3]^2 + x[3] + 1))
t[8] = @NLexpression(model,(x[2]^2 + x[2] + 1) * (x[7]^2 + x[7] + 1))
t[9] = @NLexpression(model,(x[2]^2 + x[2] + 1) * (x[10]^2 + x[10] + 1))
t[10] = @NLexpression(model,(x[3]^2 + x[3] + 1) * (x[3]^2 + x[3] + 1))
t[11] = @NLexpression(model,(x[3]^2 + x[3] + 1) * (x[7]^2 + x[7] + 1))
t[12] = @NLexpression(model,(x[3]^2 + x[3] + 1) * (x[9]^2 + x[9] + 1))
t[13] = @NLexpression(model,(x[3]^2 + x[3] + 1) * (x[10]^2 + x[10] + 1))
t[14] = @NLexpression(model,(x[3]^2 + x[3] + 1) * (x[14]^2 + x[14] + 1))
t[15] = @NLexpression(model,(x[4]^2 + x[4] + 1) * (x[4]^2 + x[4] + 1))
t[16] = @NLexpression(model,(x[4]^2 + x[4] + 1) * (x[7]^2 + x[7] + 1))
t[17] = @NLexpression(model,(x[4]^2 + x[4] + 1) * (x[11]^2 + x[11] + 1))
t[18] = @NLexpression(model,(x[4]^2 + x[4] + 1) * (x[15]^2 + x[15] + 1))
t[19] = @NLexpression(model,(x[5]^2 + x[5] + 1) * (x[5]^2 + x[5] + 1))
t[20] = @NLexpression(model,(x[5]^2 + x[5] + 1) * (x[6]^2 + x[6] + 1))
t[21] = @NLexpression(model,(x[5]^2 + x[5] + 1) * (x[10]^2 + x[10] + 1))
t[22] = @NLexpression(model,(x[5]^2 + x[5] + 1) * (x[12]^2 + x[12] + 1))
t[23] = @NLexpression(model,(x[5]^2 + x[5] + 1) * (x[16]^2 + x[16] + 1))
t[24] = @NLexpression(model,(x[6]^2 + x[6] + 1) * (x[6]^2 + x[6] + 1))
t[25] = @NLexpression(model,(x[6]^2 + x[6] + 1) * (x[8]^2 + x[8] + 1))
t[26] = @NLexpression(model,(x[6]^2 + x[6] + 1) * (x[15]^2 + x[15] + 1))
t[27] = @NLexpression(model,(x[7]^2 + x[7] + 1) * (x[7]^2 + x[7] + 1))
t[28] = @NLexpression(model,(x[7]^2 + x[7] + 1) * (x[11]^2 + x[11] + 1))
t[29] = @NLexpression(model,(x[7]^2 + x[7] + 1) * (x[13]^2 + x[13] + 1))
t[30] = @NLexpression(model,(x[8]^2 + x[8] + 1) * (x[8]^2 + x[8] + 1))
t[31] = @NLexpression(model,(x[8]^2 + x[8] + 1) * (x[10]^2 + x[10] + 1))
t[32] = @NLexpression(model,(x[8]^2 + x[8] + 1) * (x[15]^2 + x[15] + 1))
t[33] = @NLexpression(model,(x[9]^2 + x[9] + 1) * (x[9]^2 + x[9] + 1))
t[34] = @NLexpression(model,(x[9]^2 + x[9] + 1) * (x[12]^2 + x[12] + 1))
t[35] = @NLexpression(model,(x[9]^2 + x[9] + 1) * (x[16]^2 + x[16] + 1))
t[36] = @NLexpression(model,(x[10]^2 + x[10] + 1) * (x[10]^2 + x[10] + 1))
t[37] = @NLexpression(model,(x[10]^2 + x[10] + 1) * (x[14]^2 + x[14] + 1))
t[38] = @NLexpression(model,(x[11]^2 + x[11] + 1) * (x[11]^2 + x[11] + 1))
t[39] = @NLexpression(model,(x[11]^2 + x[11] + 1) * (x[13]^2 + x[13] + 1))
t[40] = @NLexpression(model,(x[11]^2 + x[11] + 1) * (x[12]^2 + x[12] + 1))
t[41] = @NLexpression(model,(x[12]^2 + x[12] + 1) * (x[14]^2 + x[14] + 1))
t[42] = @NLexpression(model,(x[13]^2 + x[13] + 1) * (x[13]^2 + x[13] + 1))
t[43] = @NLexpression(model,(x[13]^2 + x[13] + 1) * (x[14]^2 + x[14] + 1))
t[44] = @NLexpression(model,(x[14]^2 + x[14] + 1) * (x[14]^2 + x[14] + 1))
t[45] = @NLexpression(model,(x[15]^2 + x[15] + 1) * (x[15]^2 + x[15] + 1))
t[46] = @NLexpression(model,(x[16]^2 + x[16] + 1) * (x[16]^2 + x[16] + 1))

z = Dict{Int, NonlinearExpression}()

z[1] = t[1];

for i = 1:45
    z[i+1] = @NLexpression(model, z[i] + t[i+1])
end

# %%
@NLobjective(model, Min, z[46])

optimize!(model)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.12, running with linear solver MUMPS 5.5.1.
#
# Number of nonzeros in equality constraint Jacobian...:       53
# Number of nonzeros in inequality constraint Jacobian.:       16
# Number of nonzeros in Lagrangian Hessian.............:       47
#
# Total number of variables............................:       16
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# ...

# %%
# Check check results
println("Objective value: ", objective_value(model))
for i = 1:length(x)
    println("x[$i] = ", value(x[i]))
end
# Out:
# Objective value: 244.89969626160183
# x[1] = 0.03984736737686787
# x[2] = 0.7919831501006437
# x[3] = 0.20287030492298097
# x[4] = 0.8443579270215046
# x[5] = 1.2699064600764842
# x[6] = 0.9347386977654553
# x[7] = 1.6819619490580202
# x[8] = 0.15530091817676708
# x[9] = 1.5678703304506028
# x[10] = -4.567495359251005e-9
# x[11] = -6.876412353207298e-9
# x[12] = 1.5272316281986e-8
# x[13] = 0.6602040872487982
# x[14] = -2.3316030978172158e-9
# x[15] = 0.674255927178476
# x[16] = -8.23388623253694e-9
